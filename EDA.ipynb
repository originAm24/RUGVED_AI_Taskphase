# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Univariate analysis

# %%
df=pd.read_csv('co2.csv')

# %%
df.sample(5)
# Out:
#                Make                      Model            Vehicle Class  \
# 4055  MERCEDES-BENZ  AMG GLE 63 S 4MATIC COUPE           SUV - STANDARD
# 5826           FORD  Transit Connect Wagon LWB  SPECIAL PURPOSE VEHICLE
# 1249            BMW               Z4 sDRIVE28i               TWO-SEATER
# 7075     LAND ROVER      Range Rover Sport 3.0           SUV - STANDARD
# 5103          MAZDA              MAZDA3 5-DOOR                 MID-SIZE
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 4055             5.5          8          AS7         Z
# 5826             2.5          4          AS6         X
# 1249             2.0          4           M6         Z
# 7075             3.0          6          AS8         Z
# 5103             2.0          4          AS6         X
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 4055                              17.2                             12.8
# ...

# %%
sns.countplot(df['Make'])
# Out:
# <Axes: xlabel='count', ylabel='Make'>

# %%
sns.countplot(df['Vehicle Class'])
# Out:
# <Axes: xlabel='count', ylabel='Vehicle Class'>

# %%
pd.value_counts(df['Vehicle Class']).plot(kind='pie', autopct="%.2f")
# Out:
# <ipython-input-57-19896b941167>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df['Vehicle Class']).plot(kind='pie', autopct="%.2f")
# <Axes: ylabel='count'>

# %%
sns.countplot(df['Fuel Type'])
# Out:
# <Axes: xlabel='count', ylabel='Fuel Type'>

# %%
df['Fuel Type'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df['Make'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(df['Engine Size(L)'])
# Out:
# <Axes: ylabel='Engine Size(L)'>

# %%
sns.boxplot(df['Cylinders'])
# Out:
# <Axes: ylabel='Cylinders'>

# %%
df['Vehicle Class'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(df['CO2 Emissions(g/km)'])
# Out:
# <ipython-input-62-52e088df339e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CO2 Emissions(g/km)'])
# <Axes: xlabel='CO2 Emissions(g/km)', ylabel='Density'>

# %%
plt.hist(df['Engine Size(L)'])
# Out:
# (array([ 777., 1733., 1719., 1463.,  427.,  655.,  312.,  291.,    0.,
#            8.]),
#  array([0.9 , 1.65, 2.4 , 3.15, 3.9 , 4.65, 5.4 , 6.15, 6.9 , 7.65, 8.4 ]),
#  <BarContainer object of 10 artists>)

# %%
#Bivariate analysis

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
sns.scatterplot(x=df['Engine Size(L)'], y=df['CO2 Emissions(g/km)'])
# Out:
# <Axes: xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %%
sns.scatterplot(x=df['Fuel Consumption Comb (L/100 km)'], y=df['CO2 Emissions(g/km)'])
# Out:
# <Axes: xlabel='Fuel Consumption Comb (L/100 km)', ylabel='CO2 Emissions(g/km)'>

# %%
#Using hue, style and size for Multivariate analysis

# %%
sns.scatterplot(x=df['Engine Size(L)'], y=df['CO2 Emissions(g/km)'], hue=df['Fuel Type'])
# Out:
# <Axes: xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %%
sns.scatterplot(x=df['Engine Size(L)'], y=df['CO2 Emissions(g/km)'], hue=df['Fuel Type'], style=df['Transmission'])
# Out:
# <Axes: xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %%
sns.scatterplot(x=df['Engine Size(L)'], y=df['CO2 Emissions(g/km)'], size=df['Cylinders'], hue=df['Fuel Type'])
# Out:
# <Axes: xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %%
sns.barplot(x=df['Make'], y=df['CO2 Emissions(g/km)'])
# Out:
# <Axes: xlabel='Make', ylabel='CO2 Emissions(g/km)'>

# %%
heat=pd.crosstab(df['Make'], df['Fuel Type'])

# %%
sns.heatmap(heat)
# Out:
# <Axes: xlabel='Fuel Type', ylabel='Make'>

# %%
sns.heatmap(pd.crosstab(df['Make'], df['Cylinders']))
# Out:
# <Axes: xlabel='Cylinders', ylabel='Make'>

# %%
sns.barplot(x=df['Fuel Type'], y=df['CO2 Emissions(g/km)'])
# Out:
# <Axes: xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %%
sns.boxplot(df['CO2 Emissions(g/km)'])
# Out:
# <Axes: ylabel='CO2 Emissions(g/km)'>
